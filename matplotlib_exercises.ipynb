# %%
import matplotlib.pyplot as plt
import numpy as numpy
fig=plt.figure()
fig.suptitle('no axes')
fig,ax_lst=plt.subplots(2,2)

# %%
ax_lst[1]
# Out:
# array([<matplotlib.axes._subplots.AxesSubplot object at 0x000000000878EB08>,
# ...
#       dtype=object)

# %%
#一幅图(figure)需要坐标轴(axes)设置，包括坐标轴标签,坐标轴范围，刻度(大刻度，小刻度)，刻度标签，title,图例，grid,spines的设置
#所有画图函数都希望输入的是np.array或者np.masked_array,pandas data object 或者np.matrix可能会出错

# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
a=pd.DataFrame(np.random.rand(4,5),columns=list('abcde'))
a_asarray=a.values
b=np.matrix([[1,2],[3,4]])
b_asarray=np.asarray(b)

# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
x=np.linspace(0,2,100)
plt.plot(x,x,label='linear')
plt.plot(x,x*2,label='quadratic')
plt.plot(x,x*3,label='cubic')
plt.xlabel('x label')
plt.xlabel('y label')
plt.title('Simple plot')
plt.legend()

# %%
import matplotlib
matplotlib.use('pdf')#use()可以决定输出的格式，必须用在pyplot之前

# %%
plt.ioff()
plt.plot([1.6,2.7])
plt.show()
# Out:
# C:\Anaconda3\lib\site-packages\ipykernel_launcher.py:3: UserWarning: Matplotlib is currently using pdf, which is a non-GUI backend, so cannot show the figure.
#   This is separate from the ipykernel package so we can avoid doing imports until

# %%
plt.plot([1,2,3,4],[1,4,5,9],'ro')#第三个参数（format string）指明线条类型和颜色‘b-’表示蓝色实线段
plt.axis([0,6,0,20])#plt.axis(xmin,xmax,ymin,ymax)
plt.show()
# Out:
# C:\Anaconda3\lib\site-packages\ipykernel_launcher.py:3: UserWarning: Matplotlib is currently using pdf, which is a non-GUI backend, so cannot show the figure.
#   This is separate from the ipykernel package so we can avoid doing imports until

# %%
t=np.arange(0,5,0.2)
plt.plot(t,t,'r--',t,t**2,'bs',t,t**3,'g^')#
plt.show()
# Out:
# C:\Anaconda3\lib\site-packages\ipykernel_launcher.py:3: UserWarning: Matplotlib is currently using pdf, which is a non-GUI backend, so cannot show the figure.
#   This is separate from the ipykernel package so we can avoid doing imports until

# %%
#matploylib允许提供数据框关键字参数，通过相应的变量名称
data={'a':np.arange(50),'c':np.random.randint(0,50,50),'d':np.random.randn(50)}
data['b']=data['a']+10*np.random.randn(50)
data['d']=np.abs(data['d'])*100
plt.scatter('a','b',c='c',s='d',data=data)#s和c分别表示散点图的大小和颜色
plt.xlabel('entry a')
plt.ylabel('entry b')
plt.show()
# Out:
# C:\Anaconda3\lib\site-packages\ipykernel_launcher.py:7: UserWarning: Matplotlib is currently using pdf, which is a non-GUI backend, so cannot show the figure.
#   import sys

# %%
names=['group_a','group_b','group_c']
values=[1,10,100]
plt.figure(figsize=(9,3))
plt.subplot(131)
plt.bar(names,values)
plt.subplot(132)
plt.scatter(names,values)
plt.subplot(133)
plt.plot(names,values)
plt.suptitle('categorical plotting')
plt.show()
# Out:
# C:\Anaconda3\lib\site-packages\ipykernel_launcher.py:11: UserWarning: Matplotlib is currently using pdf, which is a non-GUI backend, so cannot show the figure.
#   # This is added back by InteractiveShellApp.init_path()

# %%
#通过获得线对象，利用setp()对线对象进行设置
import matplotlib.pyplot as plt
line, = plt.plot(x, y, '-')
line.set_antialiased(False) # turn off antialising

# %%
x1=y1=x2=x
y2=x2*2
line1,line2=plt.plot(x1,y1,x2,y2)
plt.setp(line1,color='r',linewidth=2.0)
plt.setp(line2,color='b',linewidth=1)
# Out:
# [None, None]

# %%
lines=plt.plot([1,2,3])#如果你传入了一个简单的list或者array，matplotlib会把它当成y值，并自动生成x值。
plt.setp(lines)
# Out:
# agg_filter: a filter function, which takes a (m, n, 3) float array and a dpi value, and returns a (m, n, 3) array
#   alpha: float
#   animated: bool
#   antialiased or aa: bool
#   clip_box: `.Bbox`
#   clip_on: bool
#   clip_path: [(`~matplotlib.path.Path`, `.Transform`) | `.Patch` | None]
#   color or c: color
#   contains: callable
#   dash_capstyle: {'butt', 'round', 'projecting'}
#   dash_joinstyle: {'miter', 'round', 'bevel'}
#   dashes: sequence of floats (on/off ink in points) or (None, None)
#   drawstyle or ds: {'default', 'steps', 'steps-pre', 'steps-mid', 'steps-post'}, default: 'default'
#   figure: `.Figure`
#   fillstyle: {'full', 'left', 'right', 'bottom', 'top', 'none'}
#   gid: str
#   in_layout: bool
#   label: object
#   linestyle or ls: {'-', '--', '-.', ':', '', (offset, on-off-seq), ...}
#   linewidth or lw: float
#   marker: marker style
#   markeredgecolor or mec: color
#   markeredgewidth or mew: float
#   markerfacecolor or mfc: color
# ...

# %%
#也可以在获得线对象以后需要使用set_property将想要改变的属性加在set_后面
x1=y1=x2=x
y2=x2*2
line1,line2=plt.plot(x1,y1,'r',x2,y2,'b')
line1.set_linewidth=2.0
line2.set_linewidth=1

# %%
plt.figure(1)
plt.subplot(2,2,1)#subplot(nrows,ncols,plot_number),(2,2,1)表示分成2行2列中的第一幅
plt.plot([1,2,3])
plt.subplot(313)#plot_number不可以超过nrows*ncols,(3,1,3)表示分成3行1列中的第3幅
plt.plot([4,5,6])
plt.figure(2)
plt.plot([7,8,9])

# %%
t=plt.xlabel('my data',fontsize=14,color='red')
mu,sigma=100,15
x=mu+sigma*np.random.randn(10000)
n,bins,patches=plt.hist(x,50,density=1,facecolor='g',alpha=0.75)#density（逻辑值）表示返回元组的第一个元素将计数归一化以形成概率密度
plt.xlabel('smarts')
plt.ylabel('probability')
plt.title('hist')
plt.axis([40,160,0,0.03])
plt.text(60,0.025,r'$\mu=100,\ \sigma=15$')#r表示该字符串是原始字符串，不会将反斜杠视为python转义
plt.grid(True)
plt.show()
# Out:
# C:\Anaconda3\lib\site-packages\ipykernel_launcher.py:11: UserWarning: Matplotlib is currently using pdf, which is a non-GUI backend, so cannot show the figure.
#   # This is added back by InteractiveShellApp.init_path()

# %%
x=np.linspace(40,160,50)
y=n#n是概率密度
plt.plot(x,y)

# %%
ax=plt.subplot(1,1,1)
t=np.arange(0,5,0.01)
s=np.cos(2*np.pi*t)
line,=plt.plot(t,s,lw=2)
plt.annotate('local max',xy=(2,1),xytext=(3,1.5),arrowprops=dict(facecolor='black',shrink=0.05))#被注解的位置用参数xy给出，文字部分的位置由xytext给出
plt.ylim(-2,2)
plt.show()
# Out:
# C:\Anaconda3\lib\site-packages\ipykernel_launcher.py:7: UserWarning: Matplotlib is currently using pdf, which is a non-GUI backend, so cannot show the figure.
#   import sys

# %%
data = {'Barton LLC': 109438.50,
'Frami, Hills and Schmidt': 103569.59,
'Fritsch, Russel and Anderson': 112214.71,
'Jerde-Hilpert': 112591.43,
'Keeling LLC': 100934.30,
'Koepp Ltd': 103660.54,
'Kulas Inc': 137351.96,
'Trantow-Barrows': 123381.38,
'White-Trantow': 135841.99,
'Will LLC': 104437.60}

# %%
from matplotlib.ticker import FuncFormatter
group_data=list(data.values())
group_names=list(data.keys())
group_mean=np.mean(group_data)

# %%
#fig表示最终整个一幅图，ax表示每一个subplot,我们从axes上调用各种方法
fig,(ax1,ax2)=plt.subplots(2,1)
ax1.barh(group_names,group_data)
ax2.plot(np.arange(0,11))
ax2.set_xlim(0,20)
# Out:
# (0, 20)

# %%
print(plt.style.available)
plt.style.use('ggplot')
# Out:
# ['bmh', 'classic', 'dark_background', 'fast', 'fivethirtyeight', 'ggplot', 'grayscale', 'seaborn-bright', 'seaborn-colorblind', 'seaborn-dark-palette', 'seaborn-dark', 'seaborn-darkgrid', 'seaborn-deep', 'seaborn-muted', 'seaborn-notebook', 'seaborn-paper', 'seaborn-pastel', 'seaborn-poster', 'seaborn-talk', 'seaborn-ticks', 'seaborn-white', 'seaborn-whitegrid', 'seaborn', 'Solarize_Light2', 'tableau-colorblind10', '_classic_test']

# %%
fig,ax=plt.subplots()
ax.barh(group_names,group_data)
labels=ax.get_xticklabels()
plt.setp(labels,rotation=90,horizontalalignment='center')#horizontalalignment设置垂直对齐方式
# Out:
# [None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None]

# %%
def currency(x, pos):
#The two args are the value and tick position
#刻度的位置由Locator对象确定，刻度标签字符串由Formatter格式化
#相对基本格式化输出采用‘%’的方法，format()功能更强大，该函数把字符串当成一个模板，通过传入的参数进行格式化，并且使用大括号‘{}’作为特殊字符代替‘%’
 if x >= 1e6:
   s = '${:1.1f}M'.format(x*1e-6)
 else:
   s = '${:1.0f}K'.format(x*1e-3)
 return s

formatter = FuncFormatter(currency)

fig, ax = plt.subplots(figsize=(6, 8))
ax.barh(group_names, group_data)
labels = ax.get_xticklabels()
plt.setp(labels, rotation=45, horizontalalignment='right')

ax.set(xlim=[-10000, 140000], xlabel='Total Revenue', ylabel='Company',
title='Company Revenue')
ax.xaxis.set_major_formatter(formatter)

# %%
fig, ax = plt.subplots(figsize=(8, 8))
ax.barh(group_names, group_data)
labels = ax.get_xticklabels()
plt.setp(labels, rotation=45, horizontalalignment='right')
# Add a vertical line, here we set the style in the function call
ax.axvline(group_mean, ls='--', color='r')
# Annotate new companies
for group in [3, 5, 8]:
    ax.text(145000, group, "New Company", fontsize=10,verticalalignment="center")
# Now we'll move our title up since it's getting a little cramped
ax.title.set(y=1.05)#上移标题
ax.set(xlim=[-10000, 140000], xlabel='Total Revenue', ylabel='Company',title='CompanyRevenue')
ax.xaxis.set_major_formatter(formatter)
ax.set_xticks([0, 25e3, 50e3, 75e3, 100e3, 125e3])
#fig.subplots_adjust(left=.1)
plt.show()
fig.savefig('sales.png')
# Out:
# C:\Anaconda3\lib\site-packages\ipykernel_launcher.py:16: UserWarning: Matplotlib is currently using pdf, which is a non-GUI backend, so cannot show the figure.
#   app.launch_new_instance()
